# %% [markdown]
# <a href="https://colab.research.google.com/github/26401-sudo/10701/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("한양과학기술고등학교 1학년 김규민 ")
# Out:
# 한양과학기술고등학교 1학년 김규민

# %%
a=20
b=50
print(f'현재 온도는 {a}도, 습도는 {b}% 입니다')
# Out:
# 현재 온도는 20도, 습도는 50% 입니다

# %%
c=90
d=3.141592
print(f'직각은 {c}도, 원주율 {d:0.2f} 입니다')
# Out:
# 직각은 90도, 원주율 3.14 입니다

# %%
print
print('2026','05','10', sep='-')
# Out:
# 2026-05-10
