# %% [markdown]
# <a href="https://colab.research.google.com/github/26401-sudo/10701/blob/main/2026_09_21ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(10 't,20,30,40)
b=(5)
c=tuple(range(3))
red=(255,0,0)
print(a. tyaa(a)
