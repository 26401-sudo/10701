# %% [markdown]
# <a href="https://colab.research.google.com/github/26401-sudo/10701/blob/main/2026_9_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='hello'
b='world'
print(a+b)
print(a*b)
print(a+b)
print(a+b)
print(a+b)

# %%
a='Hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# p
# n

# %%
a='Hello python'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# python
# Hello
# py
# Hlopt
