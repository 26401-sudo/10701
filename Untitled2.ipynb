# %% [markdown]
# <a href="https://colab.research.google.com/github/26401-sudo/10701/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
green = int(input("초록색 접시의 개수를 입입력 "))

print("\n===== 회전 초밥 영수증 =====")
print("접시 색   단가   개수   합계")

red = 2
yellow = 3
blue = 1

print(f"빨간색 1,000 {red:<5} {1000 * red:,}")
print(f"노란색 2,000 {yellow:<5} {2000 * yellow:,}")
print(f"파란색 3,000 {blue:<5} {3000 * blue:,}")
print(f"초록색 4,000 {green:<5} {4000 * green:,}")

total = 1000 * red + 2000 * yellow + 3000 * blue + 4000 * green

print(f"총 가격          {total:,}")
# Out:
# 초록색 접시의 개수를 입력 3
#
# ===== 회전 초밥 영수증 =====
# 접시 색   단가   개수   합계
# 빨간색 1,000 2     2,000
# 노란색 2,000 3     6,000
# 파란색 3,000 1     3,000
# 초록색 4,000 3     12,000
# 총 가격          23,000
